# %%
# !pip install torch torchvision torchaudio
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached torchvision-0.15.2-cp39-cp39-win_amd64.whl (1.2 MB)
# ...
#   Using cached torchaudio-2.0.2-cp39-cp39-win_amd64.whl (2.1 MB)
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ------------------------------------ 172.4/172.4 MB 366.4 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.2/1.2 MB 403.6 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.1/2.1 MB 481.0 kB/s eta 0:00:00
# ...
#   WARNING: The scripts convert-caffe2-to-onnx.exe, convert-onnx-to-caffe2.exe and torchrun.exe are installed in 'C:\Users\user\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
# !cd yolov5 & pip install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ------------------------------------ 188.5/188.5 kB 496.5 kB/s eta 0:00:00
# ...
#      ------------------------------------ 612.3/612.3 kB 481.6 kB/s eta 0:00:00
# ...
#      ------------------------------------ 805.1/805.1 kB 480.0 kB/s eta 0:00:00
# ...
#      -------------------------------------- 62.7/62.7 kB 558.5 kB/s eta 0:00:00
# ...
#   WARNING: The script cpuinfo.exe is installed in 'C:\Users\user\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts ultralytics.exe and yolo.exe are installed in 'C:\Users\user\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...

# %%
import cv2
import torch
import matplotlib.pyplot as plt
import numpy as np

# %%
model=torch.hub.load('ultralytics/yolov5','yolov5s')
# Out:
# Using cache found in C:\Users\user/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2023-8-30 Python-3.9.13 torch-2.0.1+cpu CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...

# %%
img='https://ultralytics.com/images/zidane.jpg'
result=model(img)
print(result)
# %matplotlib inline
plt.imshow(np.squeeze(result.render()));
plt.show()
# Out:
# image 1/1: 720x1280 2 persons, 2 ties
# Speed: 1173.6ms pre-process, 194.3ms inference, 2.0ms NMS per image at shape (1, 3, 384, 640)

# %%
cam = cv2.VideoCapture(0)
while cam.isOpened():
    ret, frame = cam.read()
    result=model(frame)
    cv2.imshow('YOLO', np.squeeze(result.render()))
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cam.release()
cv2.destroyAllWindows()

# %%
import uuid
import os
import time

# %%
img_path=os.path.join('data','images')
labels=['awake','drowsy']
num_imgs=20

# %%
cam = cv2.VideoCapture(0)
for label in labels:
    print(f'Collecting images for {label}')
    time.sleep(5)
    for i in range(num_imgs):
        print(f'Collecting images for {label},image number {i}',label,i)
        ret, frame = cam.read()
        imgname=os.path.join(img_path,label+'.'+str(uuid.uuid1())+'.jpg')
        cv2.imwrite(imgname,frame)
        cv2.imshow('Collection',frame)
        time.sleep(2)
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
cam.release()
cv2.destroyAllWindows()

# %%
for label in labels:
    print(f'Collecting images for {label}')
#     time.sleep(5)
    for i in range(num_imgs):
        print(f'Collecting images for {label},image number {i}',label,i)
        imgname=os.path.join(img_path,label+'.'+str(uuid.uuid1())+'.jpg')
        print(imgname)
# Out:
# ...
# data\images\awake.3d4f9cff-4767-11ee-9283-94e70bbfa701.jpg
# ...
# data\images\awake.3d4f9d00-4767-11ee-9be8-94e70bbfa701.jpg
# ...
# data\images\awake.3d4f9d01-4767-11ee-ba66-94e70bbfa701.jpg
# ...
# data\images\awake.3d4f9d02-4767-11ee-9066-94e70bbfa701.jpg
# ...
# data\images\awake.3d4f9d03-4767-11ee-9f9e-94e70bbfa701.jpg
# ...
# data\images\awake.3d4f9d04-4767-11ee-bf81-94e70bbfa701.jpg
# ...
# data\images\awake.3d4f9d05-4767-11ee-9570-94e70bbfa701.jpg
# ...
# data\images\awake.3d4f9d06-4767-11ee-956f-94e70bbfa701.jpg
# ...
# data\images\awake.3d4f9d07-4767-11ee-a640-94e70bbfa701.jpg
# ...
# data\images\awake.3d4f9d08-4767-11ee-82f0-94e70bbfa701.jpg
# ...
# data\images\awake.3d4f9d09-4767-11ee-8817-94e70bbfa701.jpg
# ...
# data\images\awake.3d4f9d0a-4767-11ee-bfa9-94e70bbfa701.jpg
# ...
# data\images\awake.3d4f9d0b-4767-11ee-9403-94e70bbfa701.jpg
# ...
# data\images\awake.3d4f9d0c-4767-11ee-ae41-94e70bbfa701.jpg
# ...
# data\images\awake.3d4f9d0d-4767-11ee-a878-94e70bbfa701.jpg
# ...
# data\images\awake.3d4f9d0e-4767-11ee-9050-94e70bbfa701.jpg
# ...

# %%
# !git clone https://github.com/tzutalin/labelImg
# Out:
# Cloning into 'labelImg'...

# %%
# !pip install pyqt5 lxml
# !cd labelImg && pyrcc5 -o libs/resources.py resources.qrc
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# !cd labelImg & python labelImg.py
# Out:
# Image:C:\Users\user\Desktop\Untitled Folder\data\images\awake.4afcde70-4767-11ee-85da-94e70bbfa701.jpg -> Annotation:C:/Users/user/Desktop/Untitled Folder/data/labels\awake.4afcde70-4767-11ee-85da-94e70bbfa701.txt
# Image:C:\Users\user\Desktop\Untitled Folder\data\images\awake.4afcde70-4767-11ee-85da-94e70bbfa701.jpg -> Annotation:C:/Users/user/Desktop/Untitled Folder/data/labels\awake.4afcde70-4767-11ee-85da-94e70bbfa701.txt
# Image:C:\Users\user\Desktop\Untitled Folder\data\images\awake.4afcde70-4767-11ee-85da-94e70bbfa701.jpg -> Annotation:C:/Users/user/Desktop/Untitled Folder/data/labels\awake.4afcde70-4767-11ee-85da-94e70bbfa701.txt
# Image:C:\Users\user\Desktop\Untitled Folder\data\images\awake.4afcde70-4767-11ee-85da-94e70bbfa701.jpg -> Annotation:C:/Users/user/Desktop/Untitled Folder/data/labels\awake.4afcde70-4767-11ee-85da-94e70bbfa701.txt
# ...

# %%
# !cd yolov5 && python train.py --img 320 --batch-size 16 --epochs 300 --data dataset.yaml --weights yolov5s.pt
# Out:
# ^C

# %%
model=torch.hub.load('ultralytics/yolov5','custom',path='yolov5/runs/train/exp6/weights/best.pt',force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to C:\Users\user/.cache\torch\hub\master.zip
# YOLOv5  2023-8-31 Python-3.9.13 torch-2.0.1+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 7055974 parameters, 0 gradients, 15.9 GFLOPs
# Adding AutoShape...
# train: weights=yolov5s.pt, cfg=, data=dataset.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=500, batch_size=16, imgsz=320, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=2, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5
# ...

# %%
img='data/images/awake.58466658-4767-11ee-b813-94e70bbfa701.jpg'
result=model(img)
print(result)
# %matplotlib inline
plt.imshow(np.squeeze(result.render()));
plt.show()
# Out:
# image 1/1: 480x640 (no detections)
# Speed: 29.7ms pre-process, 1255.3ms inference, 0.0ms NMS per image at shape (1, 3, 480, 640)
